# %%
import seaborn as sb
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import dash

# %%
df =  pd.DataFrame(pd.read_csv('/Users/damurphy/Desktop/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv'))
sub_df = df_confirmed[df_confirmed['Country/Region']=='US']
us_df = sub_df[sub_df['Province/State'] != 'US']
confirmed_df = us_df['Confirmed']
recovered_df = us_df['Recovered']
death_df = us_df['Deaths']

# %%
# plt.tick_params(axis='both', which='major', labelsize=12)
# plt.xlabel(xlabel='State', fontsize=20)
# plt.ylabel(ylabel='Confirmed Cases (# of People)', fontsize=20)
px.line(us_df, x = 'Confirmed', y = 'Province/State', title = 'Coronavirus Cases Across the US')
# Out:
# <div>
#
#
#             <div id="402446cf-554c-44a9-a884-a3d6b5bb75cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("402446cf-554c-44a9-a884-a3d6b5bb75cd")) {
#                     Plotly.newPlot(
#                         '402446cf-554c-44a9-a884-a3d6b5bb75cd',
# ...
