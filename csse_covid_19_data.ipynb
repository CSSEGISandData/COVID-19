# %% [markdown]
# # Description
#
# This Jupyter Notebook contains the code to download the JHU CSSE COVID-19 dataset from GitHub and import it into a Pandas DataFrame to be manipulated using Python.
#
# This notebook is intended to be run in [Google Colaboratory](https://colab.research.google.com/).
#
# Please note that this notebook's default kernel is Python. If you would like to run R code in it, you must pass the R code to an R kernel using Python magic functions: the cell magic function `%%R` or the line magic function `%R`.

# %% [markdown]
# # Set up notebook

# %%
# Import packages
import pandas as pd
import os
from collections import OrderedDict

# Enable interactive display of tabular data in Colab
# %load_ext google.colab.data_table

# %% [markdown]
# # Download and import data

# %%
# Download JHU CSSE COVID-19 Dataset from GitHub
# %%shell
cd /usr/local/bin
git clone https://github.com/CSSEGISandData/COVID-19.git
# Out:
# Cloning into 'COVID-19'...
# remote: Enumerating objects: 39943, done.
# remote: Total 39943 (delta 0), reused 0 (delta 0), pack-reused 39943
# Receiving objects: 100% (39943/39943), 294.52 MiB | 8.54 MiB/s, done.
# Resolving deltas: 100% (24430/24430), done.
# Checking out files: 100% (500/500), done.

# %%
# Define function to import and clean .csv files
def import_csvs(csv_directory):
  '''
  Import all .csv files in a directory into a Pandas DataFrame. Filenames are interpreted as dates.

  input:
    csv_directory: path to directory containing .csv files (string)
  '''

  # Find all .csv files in directory
  csv_filenames = {}
  for csv_filename in os.listdir(csv_directory):
    if csv_filename.endswith('.csv'):
      csv_filenames[pd.to_datetime(csv_filename.rstrip('.csv'))] = os.path.join(csv_directory, csv_filename)
  csv_filenames = OrderedDict(sorted(csv_filenames.items()))

  # Import each .csv file as a Pandas DataFrame
  dataframes_separate = []
  for (csv_date, csv_filename) in csv_filenames.items():
    print('Importing %s ...' % (csv_filename))
    df = pd.read_csv(csv_filename, engine='c', header=0)
    # Replace old versions of column names with new ones for consistency
    for old, new in {'Province/State': 'Province_State', 'Country/Region': 'Country_Region', 'Last Update': 'Last_Update', 'Latitude':'Lat', 'Longitude':'Long_', 'Admin2':'County'}.items():
      df.columns = df.columns.str.replace(old, new)
    df['Last_Update'] = pd.to_datetime(df['Last_Update']) # format dates as such
    df.replace({' ':'_'}, regex=True, inplace=True) # Replace any spaces with underscores for use in Python
    dataframes_separate.append(df)
  print('Imported all CSVs in %s.' % (csv_directory))

  # Concatenate all DataFrames into one, sort by date, and remove duplicate rows
  dataframes_combined = pd.concat(dataframes_separate, ignore_index=True).sort_values('Last_Update', ignore_index=True).drop_duplicates(ignore_index=True)

  return (dataframes_separate, dataframes_combined)


# Call functions
if __name__ == '__main__':
  csv_directory = '/usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports'
  (separated_by_date, all_data) = import_csvs(csv_directory)
# Out:
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-30-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/01-31-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-15-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-16-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-17-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-18-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-19-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-20-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-21-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-15-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-16-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-17-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-18-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-19-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-20-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-21-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-30-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-31-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-15-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-16-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-17-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-18-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-19-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-20-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-21-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/04-30-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-15-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-16-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-17-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-18-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-19-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-20-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-21-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-30-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/05-31-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-15-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-16-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-17-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-18-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-19-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-20-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-21-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-22-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-23-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-24-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-25-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-26-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-27-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-28-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-29-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/06-30-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-01-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-02-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-03-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-04-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-05-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-06-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-07-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-08-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-09-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-10-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-11-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-12-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-13-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-14-2020.csv ...
# Importing /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/07-15-2020.csv ...
# Imported all CSVs in /usr/local/bin/COVID-19/csse_covid_19_data/csse_covid_19_daily_reports.

# %%
# Show imported DataFrame
all_data
# Out:
#        Province_State  Country_Region  ... Incidence_Rate  Case-Fatality_Ratio
# 0               Anhui  Mainland_China  ...            NaN                  NaN
# 1             Ningxia  Mainland_China  ...            NaN                  NaN
# 2             Qinghai  Mainland_China  ...            NaN                  NaN
# 3             Shaanxi  Mainland_China  ...            NaN                  NaN
# 4            Shandong  Mainland_China  ...            NaN                  NaN
# ...               ...             ...  ...            ...                  ...
# 398803          Texas              US  ...     835.945664             0.000000
# 398804       Arkansas              US  ...    1189.213755             0.636943
# 398805        Indiana              US  ...     752.326032             9.339775
# 398806       Kentucky              US  ...     718.345791            10.280374
# 398807          Texas              US  ...     568.764569             1.639344
#
# [398808 rows x 14 columns]
